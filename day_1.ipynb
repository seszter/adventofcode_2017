# %% [markdown]
# ## part 1

# %%
text = '...'

# %%
int_input = [int(x) for x in text]
int_input.append(int_input[-1])

# %%
result = 0
for i in range(len(int_input)-1):
    if int_input[i] == int_input[i+1]:
        result += int_input[i]

# %%
result
# Out:
# 1150

# %% [markdown]
# ## part 2

# %%
inputlist = [int(x) for x in text]

# %%
result = 0
halfway = int(len(inputlist)/2)
for i in range(len(int_input)-1):
    if inputlist[i] == inputlist[(i + halfway) % len(inputlist)]:
        result += inputlist[i]

# %%
result
# Out:
# 1064
